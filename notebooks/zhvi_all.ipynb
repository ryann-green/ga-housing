# %%
import pandas as pd

hous_df=pd.read_csv("../inputs/housing.txt")
hous_df.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName State  \
# 0      3101         0  Los Angeles County     county        CA    CA
# 1       139         1         Cook County     county        IL    IL
# 2      1090         2       Harris County     county        TX    TX
# 3      2402         3     Maricopa County     county        AZ    AZ
# 4      2841         4    San Diego County     county        CA    CA
#
#                                   Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1    Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2  Houston-The Woodlands-Sugar Land, TX             48                201
# 3             Phoenix-Mesa-Chandler, AZ              4                 13
# 4    San Diego-Chula Vista-Carlsbad, CA              6                 73
#
#    2000-01-31  ...  2022-02-28  2022-03-31  2022-04-30  2022-05-31  \
# ...

# %%
hous_df.columns
other_cols=list(hous_df[hous_df.columns[~hous_df.columns.isin(['RegionID','SizeRank','RegionName','RegionType','StateName','State','Metro','StateCodeFIPS','MunicipalCodeFIPS'])]].columns)
pivot_cols=list(hous_df[hous_df.columns[hous_df.columns.isin(['RegionID','SizeRank','RegionName','RegionType','StateName','State','Metro','StateCodeFIPS','MunicipalCodeFIPS'])]].columns)
["','".join(pivot_cols)]
pivot_cols
# Out:
# ['RegionID',
#  'SizeRank',
#  'RegionName',
#  'RegionType',
#  'StateName',
#  'State',
#  'Metro',
#  'StateCodeFIPS',
#  'MunicipalCodeFIPS']

# %%
pd.melt(hous_df,id_vars=pivot_cols,value_vars=other_cols,var_name='Date',value_name='zhvi_all')
# Out:
#         RegionID  SizeRank          RegionName RegionType StateName State  \
# 0           3101         0  Los Angeles County     county        CA    CA
# 1            139         1         Cook County     county        IL    IL
# 2           1090         2       Harris County     county        TX    TX
# 3           2402         3     Maricopa County     county        AZ    AZ
# 4           2841         4    San Diego County     county        CA    CA
# ...          ...       ...                 ...        ...       ...   ...
# 781820       828      3104       Alpine County     county        CA    CA
# 781821      2345      3113     Hinsdale County     county        CO    CO
# 781822      1933      3114      Mineral County     county        CO    CO
# 781823      1648      3129      Daggett County     county        UT    UT
# 781824      2518      3132     San Juan County     county        CO    CO
#
#                                        Metro  StateCodeFIPS  \
# ...
